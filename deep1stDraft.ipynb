# %% [markdown]
# <a href="https://colab.research.google.com/github/sohamyedgaonkar/soham/blob/main/deep1stDraft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import io
from google.colab import files

# %%
uploded=files.upload()
#df=pd.read_csv(io.BytesIO(uploded['data.csv ']))
# Out:
#      <input type="file" id="files-175a16e4-d624-4345-a6ca-05926db7f9e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-175a16e4-d624-4345-a6ca-05926db7f9e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
#https://drive.google.com/file/d/12crJ_0mmvCabEPk6si9ItlQXgYGDSyZt/view?usp=drive_link
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/data.csv')

# %%
df=pd.read_csv(io.BytesIO(uploded['data (2).csv']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-b79804dbf344> in <cell line: 1>()
# ----> 1 df=pd.read_csv(io.BytesIO(uploded['data (2).csv']))
#
# KeyError: 'data (2).csv'

# %%
df.head()
# Out:
#      Ratio_1     Ratio_2    Ratio_3     Ratio_4    Ratio_5  Hard  Class
# 0  64.907434  511.859929  78.814484  109.103827  35.183233     2      2
# 1  65.076341  549.720444  79.076704  105.168805  37.122966     2      2
# 2  63.938928  621.619662  66.363923  121.073852  33.956582     2      2
# 3  68.143008  450.509395  82.939925  121.237390  32.721705     2      2
# 4  68.349516  522.822257  73.293800  119.902184  34.251597     2      2

# %%
df=df.sample(frac=1)

# %%
df
# Out:
#           Ratio_1     Ratio_2     Ratio_3     Ratio_4    Ratio_5  Hard  Class
# 6990    68.067876  330.641393  109.982295  106.531690  50.875073     1      1
# 12014   42.815503   71.009329  741.880268   21.138192  72.275589     0      0
# 3576    91.065736  252.029170  106.774270  105.395896  38.645850     2      2
# 2068    79.092920  281.200634   96.252507  128.730421  36.301278     2      2
# 6234    75.016247  275.284822  108.597426  100.901209  56.750353     1      1
# ...           ...         ...         ...         ...        ...   ...    ...
# 14866   41.272925  208.678875   64.864886   62.967040  67.311472     0      0
# 6594    76.676706  211.878153  123.963104  131.141733  23.871523     1      1
# 12976   82.161898  532.423228   46.150815   27.513619  57.079274     0      0
# 3761   124.148557  258.691448   58.972826  177.525241  29.285485     2      2
# 1145    72.749780  297.851780   92.380782   91.637792  59.662006     2      2
#
# [16775 rows x 7 columns]

# %%
trainY=df["Class"]
trainX=df.drop(["Class"],axis=1)

# %%
trainY.head()
trainX.head()
# Out:
#          Ratio_1     Ratio_2     Ratio_3     Ratio_4    Ratio_5  Hard
# 5804   73.055912  291.136568  121.292945  113.419645  33.937632     2
# 15111  75.638669  144.182905   86.861428  231.468807  34.714379     1
# 2256   90.727461  165.040859   94.056380  120.176784  33.578615     2
# 4042   73.910878  301.696958   93.682537  121.878444  38.335007     2
# 16111  44.451758  260.365361  182.638513   40.078369  40.947624     0

# %%
xtrain,xtest,ytrain,ytest=train_test_split(trainX,trainY,test_size=0.20,random_state=0)

# %%
clf = RandomForestClassifier(random_state=0)
clf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(random_state=0)

# %%
accuracy_score(clf.predict(xtest), ytest)
# Out:
# 0.9782414307004471

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(xtrain)
X_test = sc.transform(xtest)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 10, metric = 'euclidean', p = 2)
classifier.fit(xtrain, ytrain)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=10)

# %%
accuracy_score(classifier.predict(xtest), ytest)
# Out:
# 0.8137108792846498

# %%
#!pip install tensorflow
import tensorflow as tf
from tensorflow.keras import layers ,models
from keras.losses import SparseCategoricalCrossentropy
#import matplotlib.pylot as plt

# %%
model1=models.Sequential()
model1.add(layers.Dense(units=150,activation='relu'))
model1.add(layers.Dense(units=90,activation='relu'))
model1.add(layers.Dense(units=36,activation='relu'))
model1.add(layers.Dense(units=1,activation='linear'))

# %%
model1.compile(loss='mean_squared_error',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), metrics=['accuracy'])

# %%
ytrain = tf.one_hot(ytrain, depth=3)

# %%
print(xtrain)
print(ytrain)
# Out:
#          Ratio_1     Ratio_2     Ratio_3     Ratio_4    Ratio_5  Hard
# 4848   72.344732  264.758039   98.504166  107.632023  66.583929     2
# 15627  37.087192  291.915418  224.915157   46.574812  25.598194     0
# 1098   76.288770  365.263887   85.645354  124.470636  35.680980     2
# 9938   61.724945  364.210030  120.747464  100.567202  43.329844     1
# 6785   65.206473  383.154479  117.636582  111.394020  51.056213     1
# ...          ...         ...         ...         ...        ...   ...
# 9225   78.253882  286.866919  111.958534  106.920002  34.882591     1
# 13123  31.023628  306.791943  128.240756   46.302157  87.324082     0
# 9845   74.307640  378.014082  101.587959  111.945041  32.562133     1
# 10799  66.865468  410.960751   87.894863  110.347214  33.434669     1
# 2732   81.605260  334.830387  103.692207  125.364210  36.540903     2
#
# [13420 rows x 6 columns]
# 4848     2
# 15627    0
# 1098     2
# 9938     1
# 6785     1
#         ..
# 9225     1
# 13123    0
# ...

# %%
model1.fit(xtrain, ytrain, epochs=70, batch_size=250)
# Out:
# Epoch 1/70
# 54/54 [==============================] - 3s 6ms/step - loss: 75.6427 - accuracy: 0.3777
# Epoch 2/70
# 54/54 [==============================] - 0s 9ms/step - loss: 0.5112 - accuracy: 0.4598
# Epoch 3/70
# 54/54 [==============================] - 0s 9ms/step - loss: 0.3834 - accuracy: 0.5013
# Epoch 4/70
# 54/54 [==============================] - 0s 5ms/step - loss: 0.3522 - accuracy: 0.5057
# Epoch 5/70
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3402 - accuracy: 0.5133
# Epoch 6/70
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2772 - accuracy: 0.5254
# Epoch 7/70
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2508 - accuracy: 0.5344
# Epoch 8/70
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2113 - accuracy: 0.5501
# Epoch 9/70
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1966 - accuracy: 0.5566
# Epoch 10/70
# ...

# %%
#import numpy as np
#!pip install scikit-learn
#from sklearn.preprocessing import to_categorical

#y_hot = to_categorical(y)
#ytest = np.array(ytest)
m=(model1.predict(xtest))
for i in range(len(m)):
  if m[i]<0.5:
   m[i]=0
  elif m[i]<1.5:
    m[i]=1
  else:
    m[i]=2

print(m)
print(len(m))
accuracy_score(m,ytest)
# Out:
# 105/105 [==============================] - 0s 2ms/step
# [[2.]
#  [1.]
#  [0.]
#  ...
#  [2.]
#  [0.]
#  [1.]]
# 3355
# 0.9242921013412817

# %%
feature_columns= []

for key in xtrain.keys():
    feature_columns.append(tf.feature_column.numeric_column(key=key))
print(feature_columns)
# Out:
# WARNING:tensorflow:From <ipython-input-15-dfd7c293513a>:4: numeric_column (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Keras preprocessing layers instead, either directly or via the `tf.keras.utils.FeatureSpace` utility. Each of `tf.feature_column.*` has a functional equivalent in `tf.keras.layers` for feature preprocessing when training a Keras model.
# ...

# %%
classifier = tf.estimator.DNNClassifier(
    feature_columns = feature_columns,
    hidden_units=[63,6300,63],
    n_classes = 3
)
# Out:
# WARNING:tensorflow:From <ipython-input-16-179ee1f08298>:1: DNNClassifierV2.__init__ (from tensorflow_estimator.python.estimator.canned.dnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow_estimator/python/estimator/head/head_utils.py:59: MultiClassHead.__init__ (from tensorflow_estimator.python.estimator.head.multi_class_head) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow_estimator/python/estimator/canned/dnn.py:759: Estimator.__init__ (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# ...

# %%
def input_fn(features, labels, training=True, batch_size=256):
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))
    if training:
        dataset = dataset.shuffle(1000).repeat()

    return dataset.batch(batch_size)

# %%
classifier.train(input_fn = lambda: input_fn(xtrain, ytrain, training=True, batch_size=256),steps =5000)

# %%
import tensorflow as tf

# Ignore all GPUs
tf.config.set_visible_devices([], 'GPU')

# Ignore all warnings
tf.get_logger().setLevel('ERROR')

# %%
# !pip install tensorflow==2.12.0

# %%
def input_fn(features, labels, training=True, batch_size=256):
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))
    if training:
        dataset = dataset.shuffle(1000).repeat()

    return dataset.batch(batch_size)

# %%
estimator = tf.estimator.Estimator(model_fn=model_fn, params=params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-08a183f932be> in <cell line: 1>()
# ----> 1 estimator = tf.estimator.Estimator(model_fn=model_fn, params=params)
#
# NameError: name 'model_fn' is not defined

# %%
model = tf.keras.models.Sequential(model_fn)
